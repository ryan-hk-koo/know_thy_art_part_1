# %% [markdown]
# **Note** :
#
# - We've developed an object detection system using YOLOv8m, tailored specifically for paintings (painting as the only class)
# - When a user uploads an image, our system precisely identifies and isolates the painting, seamlessly removing any backgrounds and frames
# - This ensures that only the pure essence of the artwork is considered, optimizing the subsequent style classification process and eliminating potential interference from extraneous elements (i.e. backgrounds and frames)

# %% [markdown]
# # yolov8m

# %% [markdown]
# - Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <br>

# %% [markdown]
# - Install ultralytics : the name of the GitHub user/group that maintains the YOLOv5 repository

# %%
! pip install ultralytics

# %% [markdown]
# <br>

# %% [markdown]
# - Import the YOLO class from the ultralytics library
# - Initialize the YOLO model by loading the 'yolov8m.pt' weights

# %%
from ultralytics import YOLO
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 235MB/s]

# %% [markdown]
# <br>

# %% [markdown]
# - Train the model using the dataset specified in 'data.yaml' located in the given path
# - The training process will run for 100 epochs and stop if there's no improvement after 100 epochs (as specified by the patience)
# - There are 560 Training Data and 140 Test Data
# - The labels were created using [makesense](http://www.makesense.ai/)

# %%
model.train(data="/content/drive/MyDrive/objd_painting_2/data.yaml", epochs=100, patience=100)
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# <br>

# %% [markdown]
# # Result Curve Graphs

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/F1_curve.png')

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/PR_curve.png')

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/P_curve.png')

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/R_curve.png')

# %% [markdown]
# <br>

# %% [markdown]
# # Confusion Matrix

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/confusion_matrix.png')

# %% [markdown]
# <br>

# %% [markdown]
# # Confusion Matrix Normalized

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/confusion_matrix_normalized.png')

# %% [markdown]
# <br>

# %% [markdown]
# # labels Graphs

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/labels.jpg')

# %% [markdown]
# <br>

# %% [markdown]
# # Labels Correlogram

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/labels_correlogram.jpg')

# %% [markdown]
# <br>

# %% [markdown]
# # Results Graphs

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/results.png')

# %% [markdown]
# <br>

# %% [markdown]
# # Validation Batch Predictions

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch0_pred.jpg')

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch1_pred.jpg')

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch2_pred.jpg')
